# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# - 2013년이후 전국 아파트분양가격
# - 공공데이터 포털에 있는 데이터를 Pandas의 melt, concat, transpose와 같은 reshape 기능을 활용해 분석
# - groupby, pivot_table, info, describe, value_counts등을 통한 데이터 요약과 분석
# - 이를 통해 전혀 다른 두 데이터의 정제와 병합, 수치형 데이터의 차이를 이해하고 다양한 그래프로 시각화(barplot, lineplot, scatterplot, lmplot, swarmplot, histplot)

# %% [markdown]
# # 1. 패키지로드 & 한글설정 & 경고메세지 ignore

# %%
# 패키지 import
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# 시각화의 선명도를 높임
# %config InlineBackend.figure_format = "retina"

# 한글설정
sns.set(style='white', rc={'figure.figsize':(12,3)})
plt.rc('font', family='Malgun Gothic') # 윈도우즈
plt.rc('axes', unicode_minus=False) # 축의 - 깨짐 방지

# 다른 폰트를 기본 폰트로 하려면
# from matplotlib.font_manager import FontProperties
# font_path = 'C:\Windows\Fonts\HMKMRHD.TTF'
# font_prop = FontProperties(fname=font_path, size=10)
# plt.rc('font', family=font_prop.get_name())

# warning(경고) 안보이게
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. 데이터 다운로드
# - https://www.data.go.kr 에서 "아파트 분양 가격"을 검색한 csv 다운로드

# %% [markdown]
# ## (1) 2013년9월부터 2015년8월까지 데이터는 df_first 변수에 담아 탐색

# %%
# \를 하면 앞에 r만 붙이면 되고 /를 하면 탭키로 파일 이름을 가져올 수 있어서 편함.

df_first = pd.read_csv('C:/Users/Admin/AI/downloads/shareData/부동산/전국 평균 평당 분양가격(2013년 9월부터 2015년 8월까지).csv', encoding='cp949')
df_first.head(1)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
#
# [1 rows x 22 columns]

# %%
df_first.shape
# Out:
# (17, 22)

# %%
# 최대 display가능한 열수 수정

pd.options.display.max_columns=22 
df_first.tail(1)
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 16  제주      7674     7900     7900     7900     7900     7900     7914
#
#     2014년7월  2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  \
# 16     7914     7914     7833      7724      7724      7739     7739     7739
#
#     2015년3월  2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 16     7826     7285     7285     7343     7343     7343

# %%
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
# ...

# %%
# 열별 결측치 갯수

df_first.isna().sum()
# Out:
# 지역          0
# 2013년12월    0
# 2014년1월     0
# 2014년2월     0
# 2014년3월     0
# 2014년4월     0
# 2014년5월     0
# 2014년6월     0
# 2014년7월     0
# 2014년8월     0
# 2014년9월     0
# 2014년10월    0
# 2014년11월    0
# 2014년12월    0
# 2015년1월     0
# 2015년2월     0
# 2015년3월     0
# 2015년4월     0
# 2015년5월     0
# 2015년6월     0
# 2015년7월     0
# 2015년8월     0
# dtype: int64

# %% [markdown]
# - color map 참조 : https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
df_first_heat = df_first.set_index('지역')
df_first_heat.sample()
# Out:
#     2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  2014년7월  \
# 지역
# 울산      8090     8090     8090     8153     8153     8153     8153     8153
#
#     2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 지역
# 울산     8493     8493      8627      8891      8891     8526     8526     8629
#
#     2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 지역
# 울산     9380     9192     9190     9190     9215

# %%
plt.figure(figsize=(25,8))
sns.heatmap(df_first_heat, annot=True,
           fmt='d', # 정수로 나오게 하는것
           cmap='Purples',
           cbar=False) # 오른쪽에 바 나오는것 안나오게함
plt.xticks(rotation=45) # x축 라벨을 45도 각도로 보게 하는것
plt.ylabel(None) # y축 라벨 안보이게 하는것
plt.show()

# %% [markdown]
# ## (2) 이후 데이터는 df_last 변수에 담아 탐색

# %%
df_last = pd.read_csv('c:/Users/Admin/AI/downloads/shareData/부동산/주택도시보증공사_전국 신규 민간아파트 분양가격 동향_20241231.csv', encoding='cp949')
df_last.head()
# Out:
#   지역명                     규모구분    연도   월 분양가격(제곱미터)
# 0  서울                     모든면적  2015  10       5841
# 1  서울            전용면적 60제곱미터이하  2015  10       5652
# 2  서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10       5882
# 3  서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10       5721
# 4  서울           전용면적 102제곱미터초과  2015  10       5879

# %%
# 데이터 요약하기

df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9095 entries, 0 to 9094
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         9095 non-null   object
#  1   규모구분        9095 non-null   object
#  2   연도          9095 non-null   int64
#  3   월           9095 non-null   int64
#  4   분양가격(제곱미터)  8481 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 355.4+ KB

# %% [markdown]
# # 3. df_last의 데이터 결측치를 확인하고 대체 고민

# %%
# 열별 결측치 갯수

df_last.isna().sum()
df_last.isnull().sum()
# Out:
# 지역명             0
# 규모구분            0
# 연도              0
# 월               0
# 분양가격(제곱미터)    614
# dtype: int64

# %%
# 열별 결측치를 제외한 갯수

df_last.notna().sum()
df_last.notnull().sum()
# Out:
# 지역명           9095
# 규모구분          9095
# 연도            9095
# 월             9095
# 분양가격(제곱미터)    8481
# dtype: int64

# %%
# '분양가격(제곱미터)' 컬럼의 결측치 갯수와 결측치가 아닌 갯수, 전체 데이터 수

print('전체 갯수 :', len(df_last['분양가격(제곱미터)']), df_last.shape[0]) # len보다는 뒤에것을 더 많이씀
print('결측치가 아닌 갯수 :', df_last['분양가격(제곱미터)'].notna().sum())
print('결측치가 아닌 갯수 :', df_last['분양가격(제곱미터)'].notnull().sum())
print('결측치 갯수 :', df_last['분양가격(제곱미터)'].isna().sum())
print('결측치 갯수 :', df_last['분양가격(제곱미터)'].isnull().sum())
# Out:
# 전체 갯수 : 9095 9095
# 결측치가 아닌 갯수 : 8481
# 결측치가 아닌 갯수 : 8481
# 결측치 갯수 : 614
# 결측치 갯수 : 614

# %% [markdown]
# # 4. df_last 데이셋에 평당분양가격컬럼 추가
#
# ## (1) astype('float')나 pd.to_numeric() 사용
# ## (2) 6,222 => 6222 수정, space가 저장된 경우 nan으로 수정하는 함수를 apply나 map적용
# ## (3) df_last['분양가격(제곱미터)']*3.3

# %%
df_last.loc[0,'분양가격(제곱미터)'] # ''안에 들어있음. 현재 object
# Out:
# '5841'

# %%
# df_last.groupby('지역명')['분양가격(제곱미터)'].mean()
# df_last['분양가격(제곱미터)'] * 3.3 현재 둘다 object다보니 에러남

# %%
# df_last['분양가격(제곱미터)'].astype('float') # '5184' → 5184 로 바꾸고 싶음. 그런데 '  ','6,244' 있어서 에러남

# 숫자로 변경때 예외 발생시 예외발생말고 NaN으로 할당
pd.to_numeric(df_last['분양가격(제곱미터)'], errors='coerce').isna().sum() # 원래 결측치 갯수(614) → 스페이스,컴마 들어있는게 130개. 그런데 컴마는 데이터로 넣어야함.
# Out:
# 744

# %%
# 분양가격에 space가 있는 경우

df_last[df_last['분양가격(제곱미터)'].str.strip() == ''].shape # str.~ 하는건 시리즈에 문자열 함수를 쓰기위함
# Out:
# (126, 5)

# %%
df_last.loc[df_last['분양가격(제곱미터)'].str.strip() == '', '지역명'].value_counts()
# Out:
# 세종    30
# 제주    19
# 대구    19
# 광주    12
# 전남    11
# 대전    10
# 울산    10
# 전북     8
# 경남     5
# 서울     2
# Name: 지역명, dtype: int64

# %%
# 분양가격에 ,가 있는 경우

df_last[df_last['분양가격(제곱미터)'].notna() & (df_last['분양가격(제곱미터)'].str.find(',') != -1)] # 결측치까지 같이 나오니까 NaN이 아니고 ,가 있는것을 찾아라 라는말
# Out:
#    지역명                     규모구분    연도   월 분양가격(제곱미터)
# 80  제주                     모든면적  2015  10      2,232
# 82  제주   전용면적 60제곱미터초과 85제곱미터이하  2015  10      2,225
# 83  제주  전용면적 85제곱미터초과 102제곱미터이하  2015  10      2,583
# 84  제주           전용면적 102제곱미터초과  2015  10      2,574

# %% [markdown]
# ### apply
# - apply(함수, axis) : 1차원, 2차원(axis 지정. axis기본값0)
# - map(함수) : 1차원
# - applymap(함수) : 2차원(모든 요소들에 함수를 적용)

# %%
# 콤마가 있는 문자에서 콤마 없애기 방법1

temp = '12,523'
temp.replace(',','')
# Out:
# '12523'

# %%
# 콤마가 있는 문자에서 콤마 없애기 방법2

temp = '12,523'
tempsplited = temp.split(',')
''.join(tempsplited)
# Out:
# '12523'

# %%
# 분양가격 컬럼에 콤마(,)가 있는 경우 콤마(,)를 제거('5,123' → 5123 / '5123' → 5123)
# 공백문자가 있는 경우 np.nan로 바꾸는 함수
def commadrop(row):
    row = row.copy()
    price = row['분양가격(제곱미터)']
    
    # price(스칼라데이터)가 결측치인지 여부
        # (1) price is np.nan : 값의 타입에 상관없이 nan인지 여부 (price == np.nan 이렇게 물어보면 안됨)
        # (2) pd.isna(price), pd.isnull(값) : 값의 타입에 상관없이 nan인지 여부
        # (3) np.isnan(숫자데이터) : 값이 숫자가 아닐경우 에러. 숫자일경우 nan인지 여부를 반환 
    if price is np.nan:
        pass
    elif price.strip() == '': # space면 결측치로
        row['분양가격(제곱미터)'] = np.nan
    elif price.find(',') != -1: # 콤마(,)가 있으면 ,없애고 float 형변환
        pricesplited = price.split(',')
        row['분양가격(제곱미터)'] = float(''.join(pricesplited))
    else:
        row['분양가격(제곱미터)'] = float(price)
    return row

commadrop(df_last.loc[80]) # 콤마 제외
commadrop(df_last.loc[1]) # 그대로
commadrop(df_last.loc[28]) # 공백문자의 경우 nan
commadrop(df_last.loc[368]) # nan의 경우 nan
# Out:
# 지역명                                광주
# 규모구분          전용면적 85제곱미터초과 102제곱미터이하
# 연도                               2016
# 월                                   2
# 분양가격(제곱미터)                        NaN
# Name: 368, dtype: object

# %%
# 공백문자는 결측치로, 콤마는 제거하기를 모든 행에 적용

df_last.apply(commadrop, axis=1)
# Out:
#      지역명                     규모구분    연도   월  분양가격(제곱미터)
# 0     서울                     모든면적  2015  10      5841.0
# 1     서울            전용면적 60제곱미터이하  2015  10      5652.0
# 2     서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10      5882.0
# 3     서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10      5721.0
# 4     서울           전용면적 102제곱미터초과  2015  10      5879.0
# ...   ..                      ...   ...  ..         ...
# 9090  제주                     모든면적  2024   8      7703.0
# 9091  제주            전용면적 60제곱미터이하  2024   8         NaN
# 9092  제주   전용면적 60제곱미터초과 85제곱미터이하  2024   8      7515.0
# 9093  제주  전용면적 85제곱미터초과 102제곱미터이하  2024   8         NaN
# 9094  제주           전용면적 102제곱미터초과  2024   8      7950.0
#
# [9095 rows x 5 columns]

# %%
df_last.apply(commadrop, axis=1).isna().sum()
# Out:
# 지역명             0
# 규모구분            0
# 연도              0
# 월               0
# 분양가격(제곱미터)    740
# dtype: int64

# %% [markdown]
# ### map

# %%
# 결측치->결측치 return, 공백문자->결측치 return, '3,198' -> 3198 return, '3198'->3198 return,  
def commadrop2(price):
    if pd.isna(price):
        return np.nan
    elif price.strip() == '':
        return np.nan
    elif price.find(',') != -1:
        return float(''.join(price.split(',')))
    else:
        return float(price)

commadrop2(df_last.loc[80, '분양가격(제곱미터)']) # 콤마제외한 문자를 숫자로 
commadrop2(df_last.loc[1, '분양가격(제곱미터)']) # 콤마없는 문자를 숫자로 
commadrop2(df_last.loc[28, '분양가격(제곱미터)']) # 공백문자를 nan
commadrop2(df_last.loc[368, '분양가격(제곱미터)']) # nan을 nan
# Out:
# nan

# %% [markdown]
# - apply(함수, axis) : 1차원, 2차원(axis 지정. axis기본값0)
# - map(함수) : 1차원
# - applymap(함수) : 2차원(모든 요소들에 함수를 적용)

# %%
#df_last['분양가격(제곱미터)'].apply(commadrop2)
#df_last['분양가격(제곱미터)'].map(commadrop2)

# %%
df_last['분양가격(제곱미터)'].apply(commadrop2).isna().sum()
# Out:
# 740

# %%
df_last['분양가격(제곱미터)'].map(commadrop2).isna().sum()
# Out:
# 740

# %% [markdown]
# ### apply나 map사용 안 하기

# %%
pd.to_numeric(df_last['분양가격(제곱미터)'].str.strip().str.replace(',','')).isna().sum()
# Out:
# 740

# %%
df_last['분양가격(제곱미터)'] = pd.to_numeric(df_last['분양가격(제곱미터)'].str.strip().str.replace(',',''))

# %%
# 80(콤마있었던 행), 28(공백문자), 368(결측치)

df_last.loc[80]
df_last.loc[25]
df_last.loc[368]
df_last.loc[1]
# Out:
# 지역명                      서울
# 규모구분          전용면적 60제곱미터이하
# 연도                     2015
# 월                        10
# 분양가격(제곱미터)           5652.0
# Name: 1, dtype: object

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9095 entries, 0 to 9094
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         9095 non-null   object
#  1   규모구분        9095 non-null   object
#  2   연도          9095 non-null   int64
#  3   월           9095 non-null   int64
#  4   분양가격(제곱미터)  8355 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 355.4+ KB

# %%
df_last['평당분양가격'] = df_last['분양가격(제곱미터)']*3.3
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9095 entries, 0 to 9094
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         9095 non-null   object
#  1   규모구분        9095 non-null   object
#  2   연도          9095 non-null   int64
#  3   월           9095 non-null   int64
#  4   분양가격(제곱미터)  8355 non-null   float64
#  5   평당분양가격      8355 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 426.5+ KB

# %%
df_last['평당분양가격'].describe()
# Out:
# count     8355.000000
# mean     13032.995512
# std       5729.523419
# min       6164.400000
# 25%       9038.700000
# 50%      11513.700000
# 75%      15034.800000
# max      61917.900000
# Name: 평당분양가격, dtype: float64

# %% [markdown]
# # 5. df_last 데이터셋에서 전용면적 컬럼을 추가한다
# - 전용면적 컬럼, 필요없는 컬럼 처리로 메모리 절약

# %%
df_last.head()
# Out:
#   지역명                     규모구분    연도   월  분양가격(제곱미터)   평당분양가격
# 0  서울                     모든면적  2015  10      5841.0  19275.3
# 1  서울            전용면적 60제곱미터이하  2015  10      5652.0  18651.6
# 2  서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10      5882.0  19410.6
# 3  서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10      5721.0  18879.3
# 4  서울           전용면적 102제곱미터초과  2015  10      5879.0  19400.7

# %%
df_last['규모구분'].unique()
# Out:
# array(['모든면적', '전용면적 60제곱미터이하', '전용면적 60제곱미터초과 85제곱미터이하',
#        '전용면적 85제곱미터초과 102제곱미터이하', '전용면적 102제곱미터초과'], dtype=object)

# %%
# 전용면적, 이하, ' ' 없애기, 제곱미터 → m² (제곱 쓰는건 alt+0178), 초과 → ~

x = '전용면적 85제곱미터초과 102제곱미터이하'
# x.replace('전용면적','').replace('이하','').replace(' ','').replace('제곱미터')~~
import re
re.sub('전용면적|이하| ','',x).replace('제곱미터','m²').replace('초과','~')
# Out:
# '85m²~102m²'

# %%
# 방법1. 정규표현식 사용

df_last['전용면적'] = df_last['규모구분'].apply(lambda x : re.sub('전용면적|이하| ','',x).replace('제곱미터','m²').replace('초과','~'))
df_last.head(3)
# Out:
#   지역명                    규모구분    연도   월  분양가격(제곱미터)   평당분양가격       전용면적
# 0  서울                    모든면적  2015  10      5841.0  19275.3       모든면적
# 1  서울           전용면적 60제곱미터이하  2015  10      5652.0  18651.6       60m²
# 2  서울  전용면적 60제곱미터초과 85제곱미터이하  2015  10      5882.0  19410.6  60m²~85m²

# %%
# 방법2(비추)

df_last['전용면적'] = df_last['규모구분'].apply(lambda x : x replace('전용면적',''))
df_last['전용면적'] = df_last['규모구분'].apply(lambda x : x replace('제곱미터','m²'))
df_last['전용면적'] = df_last['규모구분'].apply(lambda x : x replace('초과','~'))
df_last['전용면적'] = df_last['규모구분'].apply(lambda x : x replace('이하',''))
df_last['전용면적'] = df_last['규모구분'].apply(lambda x : x replace(' ',''))

# %%
# 방법3

df_last['전용면적'] = df_last['규모구분'].str.replace('전용면적','').str.replace('제곱미터','m²')\
                                      .str.replace('초과','~').str.replace('이하','').str.replace(' ','')
df_last.head(3)
# Out:
#   지역명                    규모구분    연도   월  분양가격(제곱미터)   평당분양가격         전용면적
# 0  서울                    모든면적  2015  10      5841.0  19275.3         모든면적
# 1  서울           전용면적 60제곱미터이하  2015  10      5652.0  18651.6         60m²
# 2  서울  전용면적 60제곱미터초과 85제곱미터이하  2015  10      5882.0  19410.6   60m²~ 85m²

# %%
print(df_last['규모구분'].unique())
print(df_last['전용면적'].unique())
# Out:
# ['모든면적' '전용면적 60제곱미터이하' '전용면적 60제곱미터초과 85제곱미터이하' '전용면적 85제곱미터초과 102제곱미터이하'
#  '전용면적 102제곱미터초과']
# ['모든면적' ' 60m²' ' 60m²~ 85m²' ' 85m²~ 102m²' ' 102m²~']

# %% [markdown]
# # 6. 메모리 사용량을 줄이기 위해 불필요한 컬럼 제거

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9095 entries, 0 to 9094
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         9095 non-null   object
#  1   규모구분        9095 non-null   object
#  2   연도          9095 non-null   int64
#  3   월           9095 non-null   int64
#  4   분양가격(제곱미터)  8355 non-null   float64
#  5   평당분양가격      8355 non-null   float64
#  6   전용면적        9095 non-null   object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 497.5+ KB

# %%
df_last.drop(['규모구분','분양가격(제곱미터)'], axis=1, inplace=True)
df_last
# Out:
#      지역명    연도   월   평당분양가격        전용면적
# 0     서울  2015  10  19275.3        모든면적
# 1     서울  2015  10  18651.6        60m²
# 2     서울  2015  10  19410.6   60m²~85m²
# 3     서울  2015  10  18879.3  85m²~102m²
# 4     서울  2015  10  19400.7      102m²~
# ...   ..   ...  ..      ...         ...
# 9090  제주  2024   8  25419.9        모든면적
# 9091  제주  2024   8      NaN        60m²
# 9092  제주  2024   8  24799.5   60m²~85m²
# 9093  제주  2024   8      NaN  85m²~102m²
# 9094  제주  2024   8  26235.0      102m²~
#
# [9095 rows x 5 columns]

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9095 entries, 0 to 9094
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     9095 non-null   object
#  1   연도      9095 non-null   int64
#  2   월       9095 non-null   int64
#  3   평당분양가격  8355 non-null   float64
#  4   전용면적    9095 non-null   object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 355.4+ KB

# %%
# 컬럼순서 바꿔서 백업

# df_last = df_last[['지역명','전용면적','연도','월','평당분양가격']]
col = df_last.pop('전용면적') # '전용면적' 컬럼 빼서 col변수 할당 
df_last.insert(1, '전용면적', col) # 1번째 열에 col추가
df_last.head()
# Out:
#   지역명        전용면적    연도   월   평당분양가격
# 0  서울        모든면적  2015  10  19275.3
# 1  서울        60m²  2015  10  18651.6
# 2  서울   60m²~85m²  2015  10  19410.6
# 3  서울  85m²~102m²  2015  10  18879.3
# 4  서울      102m²~  2015  10  19400.7

# %%
df_last.to_csv('data/df_last.csv', index=False) # 전처리 단계 백업

# %% [markdown]
# # 7. 데이터 집계
# - GroupBy(unstack()함수 이용) vs. pivot_table()
# - 우선 결측치 대체전 데이터 집계와 시각화를 할 예정

# %%
df_last = pd.read_csv('data/df_last.csv')
df_last.head()
# Out:
#   지역명          전용면적    연도   월   평당분양가격
# 0  서울          모든면적  2015  10  19275.3
# 1  서울          60m²  2015  10  18651.6
# 2  서울    60m²~ 85m²  2015  10  19410.6
# 3  서울   85m²~ 102m²  2015  10  18879.3
# 4  서울        102m²~  2015  10  19400.7

# %% [markdown]
# - df_last.groupby(["인덱스로사용할컬럼명"])["계산할컬럼명"].연산함수()
# - df_last.pivot_table(index=["인덱스로사용할컬럼명"],
#                     values=["계산할컬럼명"],
#                     aggfunc="연산함수명")
# - pd.pivot_table(df_last, index=["인덱스로사용할컬럼명"],
#                     values=["계산할컬럼명"],
#                     aggfunc="연산함수명")

# %% [markdown]
# ## (1) 지역별 데이터수

# %%
# 지역별 데이터 수 (결측치 포함)

df_last['지역명'].value_counts() # 정렬까지
# Out:
# 서울    535
# 강원    535
# 경남    535
# 경북    535
# 전남    535
# 전북    535
# 충남    535
# 충북    535
# 세종    535
# 인천    535
# 울산    535
# 대전    535
# 광주    535
# 대구    535
# 부산    535
# 경기    535
# 제주    535
# Name: 지역명, dtype: int64

# %%
# 지역명별 데이터 행 갯수(결측치 제외) : 결과가 1차원 시리즈

df_last.groupby(['지역명'])['평당분양가격'].count().sort_values(ascending=False) # False를 하면 내림차순. ascending 안넣으면 오름차순
# Out:
# 지역명
# 경기    535
# 충북    533
# 부산    533
# 인천    531
# 서울    527
# 강원    523
# 전북    520
# 경남    516
# 충남    516
# 경북    511
# 전남    507
# 대구    495
# 광주    450
# 제주    439
# 대전    415
# 세종    409
# 울산    395
# Name: 평당분양가격, dtype: int64

# %%
# 지역명별 데이터 행 갯수(결측치 제외) : 결과가 2차원 데이터프레임 - groupby

# 1) 많이씀
df_last.groupby(['지역명'])[['평당분양가격']].count().sort_values(by='평당분양가격', ascending=False)

# 2)
df_last.groupby(['지역명'])['평당분양가격'].count().sort_values(ascending=False).to_frame()

# 3)
df_last.groupby(['지역명'])['평당분양가격'].count().reset_index().sort_values(by='평당분양가격', ascending=False)

# 4)
df_last.groupby(['지역명'], as_index=False)['평당분양가격'].count().sort_values(by='평당분양가격', ascending=False)

# 5) .T해서 보기 편하게
df_last.groupby(['지역명'])[['평당분양가격']].count().sort_values(by='평당분양가격', ascending=False).to_frame().T
# Out:
# 지역명      경기   충북   부산   인천   서울   강원   전북   경남   충남   경북   전남   대구   광주   제주  \
# 평당분양가격  535  533  533  531  527  523  520  516  516  511  507  495  450  439
#
# 지역명      대전   세종   울산
# 평당분양가격  415  409  395

# %%
# 지역명별 데이터 행 갯수(결측치 제외) : 결과가 2차원 데이터프레임 - pivot_table

# 1)
df_last.pivot_table(index=['지역명'], values='평당분양가격',
                   aggfunc='count') # 기본이 mean(평균)

# 2)
pd.pivot_table(df_last, index=['지역명'], values='평당분양가격', aggfunc='count').T
# Out:
# 지역명      강원   경기   경남   경북   광주   대구   대전   부산   서울   세종   울산   인천   전남   전북  \
# 평당분양가격  523  535  516  511  450  495  415  533  527  409  395  531  507  520
#
# 지역명      제주   충남   충북
# 평당분양가격  439  516  533

# %% [markdown]
# ## (2) 지역별 평당분양가격(평균, 최대값, ... 요약통계량)

# %%
# 지역명별 평당분양가격 최대값

df_last.pivot_table(index='지역명', values='평당분양가격', aggfunc='max').T
df_last.groupby('지역명')[['평당분양가격']].max().sort_values(by='평당분양가격', ascending=False).T
# Out:
# 지역명          서울       인천       부산       대전       대구       울산       제주  \
# 평당분양가격  61917.9  54723.9  31904.4  30851.7  30600.9  27815.7  27753.0
#
# 지역명          광주       경기       세종       강원       경남       경북       전남  \
# 평당분양가격  24951.3  24172.5  21087.0  17806.8  16566.0  15345.0  15087.6
#
# 지역명          충남       전북       충북
# 평당분양가격  14932.5  14774.1  13685.1

# %%
# 지역명별 평당분양가격 평균

df_last.pivot_table(index=['지역명'], values='평당분양가격').T
df_last.groupby('지역명')[['평당분양가격']].mean().sort_values(by='평당분양가격', ascending=False).T
# Out:
# 지역명               서울            제주           경기            부산            인천  \
# 평당분양가격  27755.404554  15912.434624  15420.03028  14896.949156  14513.232203
#
# 지역명           대구            울산         광주           대전            경남  \
# 평당분양가격  14434.52  13958.197975  12998.216  12829.56506  10776.955814
#
# 지역명               세종            경북          강원           충남           전남  \
# 평당분양가격  10741.830807  10261.553425  10078.7174  9769.541279  9224.326627
#
# 지역명              충북           전북
# 평당분양가격  8896.583302  8886.201923

# %%
# 지역명별 평당분양가격 describe(통계요약정보)

df_last.pivot_table(index=['지역명'], values='평당분양가격', aggfunc='describe')
df_last.groupby('지역명')['평당분양가격'].describe().applymap(lambda x : round(x,1)) # applymap은 안쓸수록 좋다고하심
df_last.groupby('지역명')['평당분양가격'].describe().round(1)
# Out:
#      count     mean     std      min      25%      50%      75%      max
# 지역명
# 강원   523.0  10078.7  2828.9   6639.6   7652.7   9428.1  11873.4  17806.8
# 경기   535.0  15420.0  3245.9  10160.7  13274.2  14652.0  17168.2  24172.5
# 경남   516.0  10777.0  2223.6   7260.0   9187.2  10254.8  12031.8  16566.0
# 경북   511.0  10261.6  2276.0   6949.8   8378.7   9705.3  12500.4  15345.0
# 광주   450.0  12998.2  3637.6   7428.3   9554.3  12673.6  15213.0  24951.3
# 대구   495.0  14434.5  3407.3   8259.9  11949.3  14711.4  16338.3  30600.9
# 대전   415.0  12829.6  4191.7   8002.5   9401.7  11820.6  15310.4  30851.7
# 부산   533.0  14896.9  4059.9   9669.0  12467.4  13411.2  17301.9  31904.4
# 서울   527.0  27755.4  6566.4  16701.3  22497.8  26763.0  31054.6  61917.9
# 세종   409.0  10741.8  1638.8   8487.6   9101.4  10523.7  12266.1  21087.0
# 울산   395.0  13958.2  4060.2   7992.6  10312.5  13827.0  17602.2  27815.7
# 인천   531.0  14513.2  3999.9   9537.0  11398.2  14652.0  16214.6  54723.9
# ...

# %%
# 평당분양가격을 리스트에 넣으면 이 과정을 거쳐야함
r = df_last.pivot_table(index=['지역명'], values=['평당분양가격'], aggfunc='describe')
r.columns = r.columns.droplevel(0)
r
# Out:
#            25%       50%        75%  count      max          mean      min  \
# 지역명
# 강원    7652.700   9428.10  11873.400  523.0  17806.8  10078.717400   6639.6
# 경기   13274.250  14652.00  17168.250  535.0  24172.5  15420.030280  10160.7
# 경남    9187.200  10254.75  12031.800  516.0  16566.0  10776.955814   7260.0
# 경북    8378.700   9705.30  12500.400  511.0  15345.0  10261.553425   6949.8
# 광주    9554.325  12673.65  15213.000  450.0  24951.3  12998.216000   7428.3
# 대구   11949.300  14711.40  16338.300  495.0  30600.9  14434.520000   8259.9
# 대전    9401.700  11820.60  15310.350  415.0  30851.7  12829.565060   8002.5
# 부산   12467.400  13411.20  17301.900  533.0  31904.4  14896.949156   9669.0
# 서울   22497.750  26763.00  31054.650  527.0  61917.9  27755.404554  16701.3
# 세종    9101.400  10523.70  12266.100  409.0  21087.0  10741.830807   8487.6
# 울산   10312.500  13827.00  17602.200  395.0  27815.7  13958.197975   7992.6
# ...

# %% [markdown]
# ## (3) 전용면적별 평당분양가격(평균)

# %%
df_last.groupby('전용면적')[['평당분양가격']].mean().sort_values(by='평당분양가격')
# Out:
#                     평당분양가격
# 전용면적
#  60m²         12522.774427
#  60m²~ 85m²   12619.048827
# 모든면적          12654.068098
#  85m²~ 102m²  13447.672835
#  102m²~       14066.826846

# %%
df_last.pivot_table(index='전용면적', values=['평당분양가격'])
# Out:
#                     평당분양가격
# 전용면적
#  102m²~       14066.826846
#  60m²         12522.774427
#  60m²~ 85m²   12619.048827
#  85m²~ 102m²  13447.672835
# 모든면적          12654.068098

# %% [markdown]
# ## (4) 지역별, 전용면적별 평당분양가격(평균)

# %%
# 시리즈

r = df_last.groupby(['지역명', '전용면적'])['평당분양가격'].mean() 
print(r['서울']) # 서울 모든 전용면적
print(r['서울','모든면적']) 
print(r[:,'모든면적']) # 모든지역의 모든면적
# Out:
# 전용면적
#  102m²~         29035.948515
#  60m²           27371.156075
#  60m²~ 85m²     26662.612150
#  85m²~ 102m²    28972.177143
# 모든면적            26829.678505
# Name: 평당분양가격, dtype: float64
# 26829.6785046729
# 지역명
# 강원     9538.326168
# 경기    14722.780374
# 경남    10146.513084
# 경북     9856.637383
# 광주    12798.356075
# 대구    14516.541346
# 대전    11947.572897
# 부산    14764.539252
# 서울    26829.678505
# 세종    10840.996774
# 울산    13470.835714
# 인천    13896.793458
# 전남     8970.541121
# 전북     8662.284112
# 제주    16338.885981
# 충남     9153.583178
# 충북     8547.986916
# Name: 평당분양가격, dtype: float64

# %%
# 데이터프레임

r = df_last.groupby(['지역명', '전용면적'])[['평당분양가격']].mean()
print(r.loc['서울']) # 레벨0 인덱스로 액세스
print(r.loc[('서울','모든면적')])
# print(r.loc[,'모든면적']) 에러남
print(r.xs(key='모든면적', level='전용면적')) # 레벨1 인덱스로 액세스
# Out:
#                     평당분양가격
# 전용면적
#  102m²~       29035.948515
#  60m²         27371.156075
#  60m²~ 85m²   26662.612150
#  85m²~ 102m²  28972.177143
# 모든면적          26829.678505
# 평당분양가격    26829.678505
# Name: (서울, 모든면적), dtype: float64
#            평당분양가격
# 지역명
# 강원    9538.326168
# 경기   14722.780374
# 경남   10146.513084
# 경북    9856.637383
# 광주   12798.356075
# 대구   14516.541346
# 대전   11947.572897
# 부산   14764.539252
# 서울   26829.678505
# 세종   10840.996774
# 울산   13470.835714
# 인천   13896.793458
# 전남    8970.541121
# 전북    8662.284112
# 제주   16338.885981
# 충남    9153.583178
# 충북    8547.986916

# %%
# unstack() : level0(지역명) 인덱스는 그대로 두고, level1(전용면적)을 컬럼으로

df_last.groupby(['지역명', '전용면적'])['평당분양가격'].mean().unstack().round(1)
# Out:
# 전용면적   102m²~     60m²   60m²~ 85m²   85m²~ 102m²     모든면적
# 지역명
# 강원    11314.8   9441.9       9383.5       10795.5   9538.3
# 경기    16559.1  15291.2      14787.2       15739.9  14722.8
# 경남    11522.5  10122.2      10107.8       12150.6  10146.5
# 경북    11060.6   9731.9       9828.3       10968.3   9856.6
# 광주    14749.2  12254.0      12656.0       12291.7  12798.4
# 대구    15564.0  13748.4      14494.4       13713.9  14516.5
# 대전    17662.0  11834.2      11920.1       13002.6  11947.6
# 부산    15741.4  14448.6      14745.0       14801.0  14764.5
# 서울    29035.9  27371.2      26662.6       28972.2  26829.7
# 세종    10684.5  10776.5      10775.3       10600.0  10841.0
# 울산    14809.0  13624.1      13520.4       15303.8  13470.8
# 인천    16266.6  13847.1      13879.2       14742.0  13896.8
# 전남    10206.9   9104.6       8928.4        8807.8   8970.5
# 전북     9448.1   8531.1       8623.8        9169.8   8662.3
# 제주    16770.9  14971.0      16070.6       14679.5  16338.9
# ...

# %%
df_last.pivot_table(index=['지역명','전용면적'], values='평당분양가격').unstack().head(1) # 지역명을 인덱스로 쓰고싶으면 index=['전용면적','지역명'] 이렇게 순서를 바꾸면됨
# Out:
#             평당분양가격
# 전용면적        102m²~         60m²   60m²~ 85m²   85m²~ 102m²         모든면적
# 지역명
# 강원    11314.805607  9441.885981  9383.472897  10795.481053  9538.326168

# %%
# unstack안쓰고 위에처럼 똑같이 쓰는 방법

r = df_last.pivot_table(index='지역명', columns='전용면적', values='평당분양가격')
r = r[['60m²', '60m²~85m²','85m²~102m²','102m²~', '모든면적']]
r.head()
# Out:
# 전용면적          60m²     60m²~85m²    85m²~102m²        102m²~          모든면적
# 지역명
# 강원     9441.885981   9383.472897  10795.481053  11314.805607   9538.326168
# 경기    15291.151402  14787.207477  15739.920561  16559.091589  14722.780374
# 경남    10122.231429  10107.838318  12150.634021  11522.478000  10146.513084
# 경북     9731.888571   9828.325234  10968.300000  11060.616346   9856.637383
# 광주    12254.043564  12655.962617  12291.714286  14749.190323  12798.356075

# %%
plt.figure(figsize=(25,6))
sns.heatmap(r, cmap='Purples', annot=True, fmt='.0f', cbar=False, 
            annot_kws={'color':'green', 'size':15, 'weight':'bold'})
plt.show()

# %% [markdown]
# ## (5) 연도, 지역별 평당분양가격(평균)

# %%
df_last.groupby(['연도', '지역명'])['평당분양가격'].mean().unstack().head()
# Out:
# 지역명            강원         경기            경남           경북            광주  \
# 연도
# 2015  7188.060000  11060.940   8459.220000  7464.160000   7916.700000
# 2016  7162.903846  11684.970   8496.730000  7753.405000   9190.683333
# 2017  7318.850000  12296.185   8806.600000  8288.063793   9599.700000
# 2018  8219.255000  14258.420   9327.670000  8680.776923   9526.953333
# 2019  8934.475000  15665.540  10697.615789  9050.250000  12111.675000
#
# 지역명             대구            대전         부산         서울            세종  \
# 연도
# 2015   9018.900000   8190.600000  10377.400  20315.680   8765.020000
# 2016  10282.030000   8910.733333  10743.535  21753.435   8857.805000
# 2017  12191.972222   9912.910526  11637.615  21864.095   9132.945763
# 2018  12139.252632  10234.106667  12889.965  23202.245  10340.463158
# 2019  14081.650000  12619.200000  13537.865  28286.830  11299.394118
#
# 지역명             울산            인천           전남           전북            제주  \
# 연도
# ...

# %%
df_last.pivot_table(index=['연도','지역명'], values='평당분양가격').unstack()

r = df_last.pivot_table(index='연도', columns='지역명', values='평당분양가격')
r.head()
# Out:
# 지역명            강원         경기            경남           경북            광주  \
# 연도
# 2015  7188.060000  11060.940   8459.220000  7464.160000   7916.700000
# 2016  7162.903846  11684.970   8496.730000  7753.405000   9190.683333
# 2017  7318.850000  12296.185   8806.600000  8288.063793   9599.700000
# 2018  8219.255000  14258.420   9327.670000  8680.776923   9526.953333
# 2019  8934.475000  15665.540  10697.615789  9050.250000  12111.675000
#
# 지역명             대구            대전         부산         서울            세종  \
# 연도
# 2015   9018.900000   8190.600000  10377.400  20315.680   8765.020000
# 2016  10282.030000   8910.733333  10743.535  21753.435   8857.805000
# 2017  12191.972222   9912.910526  11637.615  21864.095   9132.945763
# 2018  12139.252632  10234.106667  12889.965  23202.245  10340.463158
# 2019  14081.650000  12619.200000  13537.865  28286.830  11299.394118
#
# 지역명             울산            인천           전남           전북            제주  \
# 연도
# ...

# %%
r.loc[2024].head(1)
# Out:
# 지역명
# 강원    15622.2825
# Name: 2024, dtype: float64

# %%
r['제주'].head(1)
# Out:
# 연도
# 2015    7951.075
# Name: 제주, dtype: float64

# %%
plt.figure(figsize=(25,6))
sns.heatmap(r, cmap='Purples', annot=True, fmt='.0f',
           annot_kws={'weight':'bold','color':'indianred','size':15}, cbar=False)
plt.show()

# %% [markdown]
# - color map 참조 : https://matplotlib.org/stable/users/explain/colors/colormaps.html
# - 색상이나 style 참조 : https://wikidocs.net/92085

# %% [markdown]
# # 8. matplotlib으로 시각화(위의 도표)
# https://www.research.autodesk.com/publications/same-stats-different-graphs/
# ## (1) 지역별 결측치를 제외한 데이터수(line, bar)

# %%
result = df_last.groupby('지역명')['평당분양가격'].count().sort_values()
result.min(), result.max()
# Out:
# (395, 535)

# %%
# result.plot.line()
ax = result.plot(kind='line', color='m', linestyle='--', linewidth=2, 
                 # # title='지역별 데이터 수'를 여기에 넣으면 사이즈나 색상은 지정못함
                 # ylim=[result.min()-50, result.max()+50]
                ) 
# plt.title('지역별 데이터수', size=20, color='purple') 할당 안할때
ax.set_title('지역별 데이터수', size=20, color='purple')
ax.set_ylim([result.min()-50, result.max()+50])
ax.set_xticks(range(len(result)))
ax.set_xticklabels(result.index)
plt.show()

# %%
result.plot(kind='bar', rot=0, figsize=(18,3), color='m',
           title='지역별 데이터수', 
           # ylim = [result.min(), result.max()+50]
           )
plt.ylim([result.min()-10, result.max()+10])
plt.show()

# %% [markdown]
# ## (2) 지역별 평당분양가격 (line, bar)

# %%
result = df_last.groupby('지역명')['평당분양가격'].mean().sort_values(ascending=False)
ax = result.plot(color='m')
ax.set_xticks(range(len(result)))
ax.set_xticklabels(result.index)
plt.show()

# %%
result.plot(kind='bar', rot=30, color='m') # bar그래프는 자동적으로 x축이 다 나옴
plt.show()

# %% [markdown]
# ## (3) 전용면적별 평당분양가격(barplot)

# %%
result = df_last.groupby('전용면적')['평당분양가격'].mean()
result.plot(kind='bar', rot=0, color='m')
plt.show()

# %%
# 평당분양가격 차이를 잘 보이게 하는것

result.plot(kind='bar', rot=0, color='m', ylim=[result.min()-200, result.max()+300])

# plt.text(0-0.12, 14066+50, 14066) # x,y,출력값
for i, val in enumerate(result):
    plt.text(i-0.12, val+50, round(val), color='slateblue', fontsize=10, weight='bold')

plt.show()

# %%
for i,val in enumerate(result):
    print(i,val)
# Out:
# 0 14066.826845637583
# 1 12522.77442680776
# 2 12619.048826815642
# 3 13447.67283519553
# 4 12654.068098159509

# %% [markdown]
# ## (4) 연도별 평균 평당분양가격(line, bar)

# %%
result = df_last.groupby('연도')['평당분양가격'].mean()
print('result :', result)
print('x축 :', result.index)
print('y축 :', [round(r,1) for r in result])
# Out:
# result : 연도
# 2015     9202.735802
# 2016     9683.025000
# 2017    10372.928923
# 2018    10978.938411
# 2019    12188.293092
# 2020    13039.422449
# 2021    13636.022540
# 2022    14942.504494
# 2023    16890.920657
# 2024    18962.919231
# Name: 평당분양가격, dtype: float64
# x축 : Int64Index([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024], dtype='int64', name='연도')
# y축 : [9202.7, 9683.0, 10372.9, 10978.9, 12188.3, 13039.4, 13636.0, 14942.5, 16890.9, 18962.9]

# %%
for key, val in result.items():
    print(key, val)
# Out:
# 2015 9202.735802469135
# 2016 9683.025
# 2017 10372.928923076923
# 2018 10978.938411316649
# 2019 12188.293092105261
# 2020 13039.42244897959
# 2021 13636.022539682539
# 2022 14942.504494382021
# 2023 16890.92065677966
# 2024 18962.91923076923

# %%
result.plot(color='m', xticks=range(2015,2025), # x축이 숫자여서 가능
           ylim=[result.min()-1000, result.max()+2000]) # 글씨자리확보
# plt.text(2015, 15000, '샘플')
for year, val in result.items():
    plt.text(year-0.2, val+700, round(val), color='sienna')

plt.show()

# %%
result.plot(kind='bar', color='m', ylim=[result.min()-1000, result.max()+2000], rot=0) 

for i, val in enumerate(result):
    plt.text(i-0.21, val+400, round(val), color='slateblue')

plt.show()

# %%
# 연도와 분양가격의 상관관계

df_last[['연도','평당분양가격']].corr()
# Out:
#               연도    평당분양가격
# 연도      1.000000  0.472675
# 평당분양가격  0.472675  1.000000

# %%
df_last.groupby(['월','연도'])['평당분양가격'].mean().unstack()
r = df_last.pivot_table(index='월', columns='연도', values='평당분양가격')
plt.figure(figsize=(20,5))
sns.heatmap(r, cmap='Purples', annot=True, fmt='.0f', cbar=False, annot_kws={'weight':'bold', 'color':'chocolate'})
plt.show()

# %%
r.plot(color=['r','g','b','y','k'])
plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
r.plot(kind='box')
plt.show()

# %% [markdown]
# 범례:https://stackoverflow.com/questions/30490740/move-legend-outside-figure-in-seaborn-tsplot

# %% [markdown]
# # 9. seaborn으로 시각화
# - 위에서 시각화한 내용을 seaborn으로 시각화

# %% [markdown]
# ## (1) 지역별 평당분양가격

# %%
sns.barplot(data=df_last, x='지역명', y='평당분양가격',
           errorbar=None, # errorbar=('ci',95) : 기본값(95% 신뢰구간의 평균) / errorbar='sd' : 실제값과 표준편차
           palette='twilight') 
plt.show()

# %%
# 정렬된 순서로 시각화

result = df_last.groupby('지역명')['평당분양가격'].mean().sort_values(ascending=False)
sns.barplot(data=df_last, x='지역명', y='평당분양가격',
           errorbar=None,
           order=result.index,
           palette='twilight') 
plt.show()

# %%
result
# Out:
# 지역명
# 서울    27755.404554
# 제주    15912.434624
# 경기    15420.030280
# 부산    14896.949156
# 인천    14513.232203
# 대구    14434.520000
# 울산    13958.197975
# 광주    12998.216000
# 대전    12829.565060
# 경남    10776.955814
# 세종    10741.830807
# 경북    10261.553425
# 강원    10078.717400
# 충남     9769.541279
# 전남     9224.326627
# 충북     8896.583302
# 전북     8886.201923
# Name: 평당분양가격, dtype: float64

# %%
# 값 넣기

result = df_last.groupby('지역명')['평당분양가격'].mean().sort_values(ascending=False)
ax = sns.barplot(data=df_last, x='지역명', y='평당분양가격',
                   errorbar=None,
                   order=result.index,
                   palette='twilight') 
ax.set_title('지역별 평당분양가격')
ax.set_ylim([0,35000])
for i, val in enumerate(result):
    ax.text(i-0.4, val+400, round(val), color='peru', weight='bold')

plt.show()

# %%
# 위랑 아래가 똑같은 그래프지만 이것보다는 위가 더 가독성이 좋음

ax = sns.barplot(x=result.index, y=result,
                   errorbar=None,
                   order=result.index,
                   palette='twilight') 
ax.set_title('지역별 평당분양가격')
ax.set_ylim([0,35000])
for i, val in enumerate(result):
    ax.text(i-0.4, val+400, round(val), color='peru', weight='bold')

plt.show()

# %% [markdown]
# ## (2) 연도별 평당분양가격

# %% [markdown]
# ## (3) 그 외 lineplot, relplot, boxplot, violinplot, boxexplot, regplot, swarmplot

# %% [markdown]
# https://stackoverflow.com/questions/30490740/move-legend-outside-figure-in-seaborn-tsplot : 범례사용(교안 20page)

# %% [markdown]
# # 10. 구조가 다른 df_first와 df_last를 연결 후 분석
# ## (1) concat
# - new_first :df_first를 [지역명, 연도, 월, 평당분양가격]으로 변환
# - new_last : df_last를 [지역명, 연도, 월, 평당분양가격]으로 변환
#                 (전용면적이 모든면적인 행만 추출후, 전용면적 열을 삭제)

# %% [markdown]
# ## (2) 결측치 대체(연도별, 지역별 중위값)

# %% [markdown]
# ## (3) df.csv파일로 출력

# %% [markdown]
# ## (4) 7절부터 9절까지 분석을 한다(전용면적별 분석은 불가)
#
# - 지역명별 데이터 갯수는 결측치가 없어서 동일(groupby나 pivot_table등으로 확인)
# - 지역명별 평당분양가격(groupby, pivot_table, plot, seaborn 연습)
# - 연도별 지역명별 평당분양가격(groupby, pivot_table, plot, seaborn 연습)
#
# ### ① 지역명별 데이터 행 갯수 : 결과가 1차원 시리즈

# %% [markdown]
# ### ② 지역별 평당분양가격(평균, 최대값, ... 요약통계량)

# %%
# 지역명당 평당분양가격 시각화(lineplot과 matplotlib의 bar, sns의 barplot)

# %% [markdown]
# ### ③ 연도별 평당분양가격(평균)

# %%
# 연도별 평당분양가격 시각화(lineplot과 matplotlib의 bar, sns의 barplot)

# %% [markdown]
# ### ④ 연도, 지역별 평당분양가격(평균)

# %%
# 연도별, 지역별 평당분양가격 시각화(heatmap)

# %%
# 년도별 평균 평당분양가격의 추이

# %%
# 위의 그래프가 겹쳐서 작 보이지 않아 분리

# %%
# 관계형 그래프의 서브플롯을 그리는 함수는 relplot
# 범주형 그래프의 서브플롯을 그리는 함수는 catplot

# %%
# 연도별 평당분양가격의 사분위수

# %%
# 연도별 평당분양가격의 사분위수(분포포함 boxenplot)

# %%
# 연도별 평당분양가격의 사분위수(분포포함 violinplot)

# %%
# 연도에 따른 평당분양가격을 회귀식으로 시각화

# %%
# swarmplot은 많은 데이터를 그리기에는 시간이 많이 걸려 5%만 sampling후 그릴 것을 추천
# 연도별 평당분양가격 산점도

# %%
# 분양가격을 hist
